# %%
#Install dependencies

# %pip install anthropic python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: anthropic in /Users/luciehrbkova/Library/Python/3.9/lib/python/site-packages (0.109.2)
# Requirement already satisfied: python-dotenv in /Users/luciehrbkova/Library/Python/3.9/lib/python/site-packages (1.2.1)
# Requirement already satisfied: sniffio in /Users/luciehrbkova/Library/Python/3.9/lib/python/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/luciehrbkova/Library/Python/3.9/lib/python/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /Users/luciehrbkova/Library/Python/3.9/lib/python/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /Users/luciehrbkova/Library/Python/3.9/lib/python/site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/luciehrbkova/Library/Python/3.9/lib/python/site-packages (from anthropic) (0.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/luciehrbkova/Library/Python/3.9/lib/python/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/luciehrbkova/Library/Python/3.9/lib/python/site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/luciehrbkova/Library/Python/3.9/lib/python/site-packages (from anthropic) (4.12.1)
# Requirement already satisfied: idna>=2.8 in /Users/luciehrbkova/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->anthropic) (3.18)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/luciehrbkova/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->anthropic) (1.3.1)
# Requirement already satisfied: httpcore==1.* in /Users/luciehrbkova/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: certifi in /Users/luciehrbkova/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.6.17)
# Requirement already satisfied: h11>=0.16 in /Users/luciehrbkova/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/luciehrbkova/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/luciehrbkova/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/luciehrbkova/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Applications/Xcode-16.2.0.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
#Load variables
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
#Create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
#Make a request
message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "What is quantum computing? Answer in one sentence"
        }
    ]
)

# %%
message.content[0].text
